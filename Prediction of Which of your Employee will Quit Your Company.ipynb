# %%
import numpy as np
import pandas as pd

hr_df=pd.read_csv(r'C:\Python37\Projects\ALL ML-DL-DS Projects from Udemy and other Sources\Data_Science\Data Science and Deep Learning for Business\datascienceforbusiness-master\hr_data.csv')

# %%
hr_df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary
# 0                  0     1                      0      sales     low
# 1                  0     1                      0      sales  medium
# 2                  0     1                      0      sales  medium
# 3                  0     1                      0      sales     low
# 4                  0     1                      0      sales     low
# ...              ...   ...                    ...        ...     ...
# 14994              0     1                      0    support     low
# 14995              0     1                      0    support     low
# 14996              0     1                      0    support     low
# 14997              0     1                      0    support     low
# 14998              0     1                      0    support     low
#
# [14999 rows x 9 columns]

# %%
#Numerical Analysis

# %%
hr_df.shape
# Out:
# (14999, 9)

# %%
hr_df.size
# Out:
# 134991

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
# dtypes: int64(7), object(2)
# memory usage: 1.0+ MB

# %%
hr_df['department'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
hr_df['salary'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
#Loading our Employee Satisfaction Data

# %%
s_df=pd.read_excel(r'C:\Python37\Projects\ALL ML-DL-DS Projects from Udemy and other Sources\Data_Science\Data Science and Deep Learning for Business\datascienceforbusiness-master\employee_satisfaction_evaluation.xlsx')

# %%
s_df
# Out:
#        EMPLOYEE #  satisfaction_level  last_evaluation
# 0            1003                0.38             0.53
# 1            1005                0.80             0.86
# 2            1486                0.11             0.88
# 3            1038                0.72             0.87
# 4            1057                0.37             0.52
# ...           ...                 ...              ...
# 14994       87670                0.40             0.57
# 14995       87673                0.37             0.48
# 14996       87679                0.37             0.53
# 14997       87681                0.11             0.96
# 14998       87684                0.37             0.52
#
# [14999 rows x 3 columns]

# %%
#Merging and Joining

# %%
main_df= hr_df.set_index('employee_id').join(s_df.set_index('EMPLOYEE #'))

# %%
main_df=main_df.reset_index()

# %%
main_df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary  \
# 0                  0     1                      0      sales     low
# 1                  0     1                      0      sales  medium
# 2                  0     1                      0      sales  medium
# 3                  0     1                      0      sales     low
# 4                  0     1                      0      sales     low
# ...              ...   ...                    ...        ...     ...
# 14994              0     1                      0    support     low
# 14995              0     1                      0    support     low
# 14996              0     1                      0    support     low
# 14997              0     1                      0    support     low
# 14998              0     1                      0    support     low
#
#        satisfaction_level  last_evaluation
# 0                    0.38             0.53
# 1                    0.80             0.86
# 2                    0.11             0.88
# 3                    0.72             0.87
# 4                    0.37             0.52
# ...                   ...              ...
# 14994                0.40             0.57
# 14995                0.37             0.48
# 14996                0.37             0.53
# 14997                0.11             0.96
# 14998                0.37             0.52
#
# [14999 rows x 11 columns]

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
#  9   satisfaction_level     14972 non-null  float64
#  10  last_evaluation        14972 non-null  float64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 1.3+ MB

# %%
main_df[main_df.isnull().any(axis=1)]
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 18            3794               2                   160                   3
# 19            1140               5                   262                   5
# 33            1230               2                   140                   3
# 53            1340               2                   132                   3
# 72           22316               2                   149                   3
# 92            1581               2                   143                   3
# 107          17376               2                   148                   3
# 120           1739               4                   158                   4
# 137           1847               2                   129                   3
# 175          32923               4                   164                   2
# 191           2160               4                   226                   6
# 352           3150               4                   262                   6
# 376           3250               4                   296                   2
# 402           3405               5                   275                   5
# 427          78130               3                   180                   4
# 442           3635               5                   229                   5
# 468           3755               5                   245                   5
# 543           4150               5                   237                   5
# 892          43615               4                   276                   5
# 1588         42185               5                   264                   5
# 1934         11895               4                   225                   5
# 2343         14170               3                   115                   2
# 2743         16445               5                   149                   2
# 3170         18980               5                   186                   2
# 3609         21580               3                   263                   2
# 3776         22555               4                   214                   3
# 4122         24505               3                   192                   3
# 4740         27950               3                   253                   3
# 5028         29640               4                   180                   4
# 6453         38090               5                   166                   2
# 7005         41535               4                   150                   3
# 7516         44460               4                   264                   3
# 8630         50960               4                   167                   3
# 9455         55770               4                   270                   3
# 9901         58630               5                   252                   3
# 10647        62595               4                   165                   3
# 10962        64350               5                   233                   3
# 11575        20215               3                   192                   7
# 11967        70005               3                   148                   3
# 12422        72475               5                   257                   5
# 12853        74880               3                   136                   2
# 13482        78780               3                   207                   7
# 13925        81315               3                   133                   3
#
#        Work_accident  left  promotion_last_5years   department  salary  \
# 18                 1     1                      1        sales     low
# 19                 0     1                      0        sales     low
# 33                 0     1                      0           hr     low
# 53                 0     1                      0      support     low
# 72                 0     1                      0  product_mng    high
# 92                 0     1                      0        sales     low
# 107                0     1                      0   accounting  medium
# 120                1     1                      0    technical     low
# 137                0     1                      0   management     low
# 175                0     1                      0        sales     low
# 191                1     1                      0    technical  medium
# 352                0     1                      0      support     low
# 376                0     1                      0           IT  medium
# 402                0     1                      0        sales     low
# 427                0     1                      0    technical  medium
# 442                0     1                      0   management     low
# 468                0     1                      0        sales     low
# 543                0     1                      0        sales  medium
# 892                0     1                      0      support     low
# 1588               0     1                      0           IT  medium
# 1934               0     1                      0        sales  medium
# 2343               1     0                      0      support     low
# 2743               0     0                      0        RandD     low
# 3170               0     0                      0    technical  medium
# 3609               1     0                      0        sales  medium
# 3776               0     0                      0    technical  medium
# 4122               0     0                      0    marketing    high
# 4740               0     0                      0    marketing  medium
# 5028               0     0                      0  product_mng  medium
# 6453               0     0                      0    technical    high
# 7005               0     0                      0    technical     low
# 7516               0     0                      0    technical     low
# 8630               1     0                      0    technical     low
# 9455               0     0                      0  product_mng     low
# 9901               0     0                      0      support  medium
# 10647              0     0                      0    technical     low
# 10962              0     0                      0      support     low
# 11575              0     0                      0   management    high
# 11967              0     0                      0           IT     low
# 12422              0     1                      0    technical  medium
# 12853              0     0                      0           hr    high
# 13482              0     0                      1   management  medium
# 13925              0     0                      0        sales  medium
#
#        satisfaction_level  last_evaluation
# 18                    NaN              NaN
# 19                    NaN             0.89
# 33                    NaN              NaN
# 53                    NaN              NaN
# 72                    NaN              NaN
# 92                    NaN              NaN
# 107                   NaN              NaN
# 120                   NaN              NaN
# 137                   NaN              NaN
# 175                   NaN              NaN
# 191                  0.92              NaN
# 352                   NaN             0.91
# 376                  0.56              NaN
# 402                   NaN             1.00
# 427                   NaN             0.60
# 442                  0.77              NaN
# 468                   NaN             0.92
# 543                  0.89              NaN
# 892                  0.74              NaN
# 1588                  NaN             0.81
# 1934                 0.78              NaN
# 2343                  NaN             0.97
# 2743                 0.62              NaN
# 3170                  NaN              NaN
# 3609                 0.95              NaN
# 3776                  NaN             0.68
# 4122                 0.86              NaN
# 4740                  NaN             0.95
# 5028                 0.64              NaN
# 6453                  NaN             0.78
# 7005                 0.82              NaN
# 7516                  NaN             0.97
# 8630                 0.90              NaN
# 9455                  NaN             0.88
# 9901                 0.92              NaN
# 10647                 NaN             0.69
# 10962                0.65              NaN
# 11575                 NaN              NaN
# 11967                0.82              NaN
# 12422                 NaN             1.00
# 12853                 NaN             0.70
# 13482                0.58              NaN
# 13925                 NaN             0.75

# %%
main_df.describe()
# Out:
#         employee_id  number_project  average_montly_hours  time_spend_company  \
# count  14999.000000    14999.000000          14999.000000        14999.000000
# mean   45424.627575        3.803054            201.050337            3.498233
# std    25915.900127        1.232592             49.943099            1.460136
# min     1003.000000        2.000000             96.000000            2.000000
# 25%    22872.500000        3.000000            156.000000            3.000000
# 50%    45448.000000        4.000000            200.000000            3.000000
# 75%    67480.500000        5.000000            245.000000            4.000000
# max    99815.000000        7.000000            310.000000           10.000000
#
#        Work_accident          left  promotion_last_5years  satisfaction_level  \
# count   14999.000000  14999.000000           14999.000000        14972.000000
# mean        0.144610      0.238083               0.021268            0.612830
# std         0.351719      0.425924               0.144281            0.248714
# min         0.000000      0.000000               0.000000            0.090000
# 25%         0.000000      0.000000               0.000000            0.440000
# 50%         0.000000      0.000000               0.000000            0.640000
# 75%         0.000000      0.000000               0.000000            0.820000
# max         1.000000      1.000000               1.000000            1.000000
#
#        last_evaluation
# count     14972.000000
# mean          0.716125
# std           0.171138
# min           0.360000
# 25%           0.560000
# 50%           0.720000
# 75%           0.870000
# max           1.000000

# %%
main_df.fillna(main_df.mean(),inplace=True)

# %%
main_df[main_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [employee_id, number_project, average_montly_hours, time_spend_company, Work_accident, left, promotion_last_5years, department, salary, satisfaction_level, last_evaluation]
# Index: []

# %%
main_df.loc[main_df['employee_id']==1340]
# Out:
#     employee_id  number_project  average_montly_hours  time_spend_company  \
# 53         1340               2                   132                   3
#
#     Work_accident  left  promotion_last_5years department salary  \
# 53              0     1                      0    support    low
#
#     satisfaction_level  last_evaluation
# 53             0.61283         0.716125

# %%
main_df.drop(columns='employee_id',inplace=True)

# %%
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary  \
# 0                  0     1                      0      sales     low
# 1                  0     1                      0      sales  medium
# 2                  0     1                      0      sales  medium
# 3                  0     1                      0      sales     low
# 4                  0     1                      0      sales     low
# ...              ...   ...                    ...        ...     ...
# 14994              0     1                      0    support     low
# 14995              0     1                      0    support     low
# 14996              0     1                      0    support     low
# 14997              0     1                      0    support     low
# 14998              0     1                      0    support     low
#
#        satisfaction_level  last_evaluation
# 0                    0.38             0.53
# 1                    0.80             0.86
# 2                    0.11             0.88
# 3                    0.72             0.87
# 4                    0.37             0.52
# ...                   ...              ...
# 14994                0.40             0.57
# 14995                0.37             0.48
# 14996                0.37             0.53
# 14997                0.11             0.96
# 14998                0.37             0.52
#
# [14999 rows x 10 columns]

# %%
#main_df['department'].values_counts()

# %%
main_df.groupby('department').sum()
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# department
# IT                     4683                248119                4256
# RandD                  3033                158030                2650
# accounting             2934                154292                2702
# hr                     2701                146828                2480
# management             2432                126787                2711
# marketing              3164                171073                3063
# product_mng            3434                180369                3135
# sales                 15634                831773               14631
# support                8479                447490                7563
# technical             10548                550793                9279
#
#              Work_accident  left  promotion_last_5years  satisfaction_level  \
# department
# IT                     164   273                      3           758.17283
# RandD                  134   121                     27           487.80000
# accounting              96   204                     14           446.68283
# hr                      89   215                     15           442.53566
# management             103    91                     69           391.76566
# marketing              138   203                     43           530.62283
# product_mng            132   198                      0           559.19566
# sales                  587  1014                    100          2543.77981
# support                345   555                     20          1377.90849
# technical              381   697                     28          1653.37264
#
#              last_evaluation
# department
# IT                879.452250
# RandD             560.446125
# accounting        550.706125
# hr                524.006125
# management        456.234499
# marketing         613.946125
# product_mng       644.662250
# sales            2938.236749
# support          1611.534499
# technical        1961.930624

# %%
main_df.groupby('department').mean()
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# department
# IT                 3.816626            202.215974            3.468623
# RandD              3.853875            200.800508            3.367217
# accounting         3.825293            201.162973            3.522816
# hr                 3.654939            198.684709            3.355886
# management         3.860317            201.249206            4.303175
# marketing          3.687646            199.385781            3.569930
# product_mng        3.807095            199.965632            3.475610
# sales              3.776329            200.911353            3.534058
# support            3.803948            200.758188            3.393001
# technical          3.877941            202.497426            3.411397
#
#              Work_accident      left  promotion_last_5years  \
# department
# IT                0.133659  0.222494               0.002445
# RandD             0.170267  0.153748               0.034307
# accounting        0.125163  0.265971               0.018253
# hr                0.120433  0.290934               0.020298
# management        0.163492  0.144444               0.109524
# marketing         0.160839  0.236597               0.050117
# product_mng       0.146341  0.219512               0.000000
# sales             0.141787  0.244928               0.024155
# support           0.154778  0.248991               0.008973
# technical         0.140074  0.256250               0.010294
#
#              satisfaction_level  last_evaluation
# department
# IT                     0.617908         0.716750
# RandD                  0.619822         0.712130
# accounting             0.582377         0.718000
# hr                     0.598830         0.709075
# management             0.621850         0.724182
# marketing              0.618442         0.715555
# product_mng            0.619951         0.714703
# sales                  0.614440         0.709719
# support                0.618173         0.722985
# technical              0.607858         0.721298

# %%
main_df['left'].value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
#Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\thero\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# C:\Users\thero\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
def plot_corr(df,size=10):
    
    corr=df.corr()
    fig,ax=plt.subplots(figsize=(size,size))
    ax.legend()
    cax=ax.matshow(corr)
    fig.colorbar(cax)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
    plt.yticks(range(len(corr.columns)), corr.columns)
    

plot_corr(main_df)
# Out:
# No handles with labels found to put in legend.

# %%
plt.bar(x=main_df['left'],height=main_df['satisfaction_level'])
# Out:
# <BarContainer object of 14999 artists>

# %%
sns.barplot(x='left',y='satisfaction_level',data=main_df)

# %%
sns.barplot(x='promotion_last_5years',y='satisfaction_level',data=main_df,hue='left')

# %%
sns.pairplot(main_df,hue='left')
# Out:
# C:\Users\thero\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\thero\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\thero\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\thero\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
#Data Preprocessing

# %%
y=main_df[['department','salary']]

# %%
y
# Out:
#       department  salary
# 0          sales     low
# 1          sales  medium
# 2          sales  medium
# 3          sales     low
# 4          sales     low
# ...          ...     ...
# 14994    support     low
# 14995    support     low
# 14996    support     low
# 14997    support     low
# 14998    support     low
#
# [14999 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

k=le.fit_transform(main_df['salary'])

# %%
k
# Out:
# array([1, 2, 2, ..., 1, 1, 1])

# %%
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary  \
# 0                  0     1                      0      sales     low
# 1                  0     1                      0      sales  medium
# 2                  0     1                      0      sales  medium
# 3                  0     1                      0      sales     low
# 4                  0     1                      0      sales     low
# ...              ...   ...                    ...        ...     ...
# 14994              0     1                      0    support     low
# 14995              0     1                      0    support     low
# 14996              0     1                      0    support     low
# 14997              0     1                      0    support     low
# 14998              0     1                      0    support     low
#
#        satisfaction_level  last_evaluation
# 0                    0.38             0.53
# 1                    0.80             0.86
# 2                    0.11             0.88
# 3                    0.72             0.87
# 4                    0.37             0.52
# ...                   ...              ...
# 14994                0.40             0.57
# 14995                0.37             0.48
# 14996                0.37             0.53
# 14997                0.11             0.96
# 14998                0.37             0.52
#
# [14999 rows x 10 columns]

# %%
main_df['salary_num']=k

# %%
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary  \
# 0                  0     1                      0      sales     low
# 1                  0     1                      0      sales  medium
# 2                  0     1                      0      sales  medium
# 3                  0     1                      0      sales     low
# 4                  0     1                      0      sales     low
# ...              ...   ...                    ...        ...     ...
# 14994              0     1                      0    support     low
# 14995              0     1                      0    support     low
# 14996              0     1                      0    support     low
# 14997              0     1                      0    support     low
# 14998              0     1                      0    support     low
#
#        satisfaction_level  last_evaluation  salary_num
# 0                    0.38             0.53           1
# 1                    0.80             0.86           2
# 2                    0.11             0.88           2
# 3                    0.72             0.87           1
# 4                    0.37             0.52           1
# ...                   ...              ...         ...
# 14994                0.40             0.57           1
# 14995                0.37             0.48           1
# 14996                0.37             0.53           1
# 14997                0.11             0.96           1
# 14998                0.37             0.52           1
#
# [14999 rows x 11 columns]

# %%
main_df.loc[main_df['salary']=='high']
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 72                  2                   149                   3
# 111                 6                   289                   4
# 189                 2                   156                   3
# 267                 2                   129                   3
# 306                 2                   149                   3
# ...               ...                   ...                 ...
# 14829               2                   148                   3
# 14868               2                   130                   3
# 14902               2                   159                   3
# 14941               2                   131                   3
# 14980               5                   238                   5
#
#        Work_accident  left  promotion_last_5years   department salary  \
# 72                 0     1                      0  product_mng   high
# 111                0     1                      0           hr   high
# 189                0     1                      0    technical   high
# 267                0     1                      0    technical   high
# 306                0     1                      0    marketing   high
# ...              ...   ...                    ...          ...    ...
# 14829              0     1                      0    marketing   high
# 14868              0     1                      0      support   high
# 14902              0     1                      0           hr   high
# 14941              0     1                      0        RandD   high
# 14980              0     1                      0    technical   high
#
#        satisfaction_level  last_evaluation  salary_num
# 72                0.61283         0.716125           0
# 111               0.09000         0.850000           0
# 189               0.44000         0.510000           0
# 267               0.45000         0.530000           0
# 306               0.37000         0.460000           0
# ...                   ...              ...         ...
# 14829             0.45000         0.570000           0
# 14868             0.43000         0.550000           0
# 14902             0.45000         0.460000           0
# 14941             0.43000         0.490000           0
# 14980             0.76000         0.890000           0
#
# [1237 rows x 11 columns]

# %%
main_df.drop(['salary'],axis=1,inplace=True)

# %%
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  \
# 0                  0     1                      0      sales
# 1                  0     1                      0      sales
# 2                  0     1                      0      sales
# 3                  0     1                      0      sales
# 4                  0     1                      0      sales
# ...              ...   ...                    ...        ...
# 14994              0     1                      0    support
# 14995              0     1                      0    support
# 14996              0     1                      0    support
# 14997              0     1                      0    support
# 14998              0     1                      0    support
#
#        satisfaction_level  last_evaluation  salary_num
# 0                    0.38             0.53           1
# 1                    0.80             0.86           2
# 2                    0.11             0.88           2
# 3                    0.72             0.87           1
# 4                    0.37             0.52           1
# ...                   ...              ...         ...
# 14994                0.40             0.57           1
# 14995                0.37             0.48           1
# 14996                0.37             0.53           1
# 14997                0.11             0.96           1
# 14998                0.37             0.52           1
#
# [14999 rows x 10 columns]

# %%
z=le.fit_transform(main_df['department'])

# %%
z
# Out:
# array([7, 7, 7, ..., 8, 8, 8])

# %%
main_df['department_num']=z

# %%
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  \
# 0                  0     1                      0      sales
# 1                  0     1                      0      sales
# 2                  0     1                      0      sales
# 3                  0     1                      0      sales
# 4                  0     1                      0      sales
# ...              ...   ...                    ...        ...
# 14994              0     1                      0    support
# 14995              0     1                      0    support
# 14996              0     1                      0    support
# 14997              0     1                      0    support
# 14998              0     1                      0    support
#
#        satisfaction_level  last_evaluation  salary_num  department_num
# 0                    0.38             0.53           1               7
# 1                    0.80             0.86           2               7
# 2                    0.11             0.88           2               7
# 3                    0.72             0.87           1               7
# 4                    0.37             0.52           1               7
# ...                   ...              ...         ...             ...
# 14994                0.40             0.57           1               8
# 14995                0.37             0.48           1               8
# 14996                0.37             0.53           1               8
# 14997                0.11             0.96           1               8
# 14998                0.37             0.52           1               8
#
# [14999 rows x 11 columns]

# %%
main_df.loc[main_df['department']=='IT']
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 61                  7                   308                   4
# 62                  6                   244                   5
# 63                  2                   132                   3
# 64                  6                   286                   4
# 65                  6                   161                   4
# ...               ...                   ...                 ...
# 14930               6                   268                   4
# 14931               5                   240                   5
# 14932               2                   127                   3
# 14933               7                   264                   4
# 14938               4                   271                   5
#
#        Work_accident  left  promotion_last_5years department  \
# 61                 0     1                      0         IT
# 62                 0     1                      0         IT
# 63                 0     1                      0         IT
# 64                 0     1                      0         IT
# 65                 0     1                      0         IT
# ...              ...   ...                    ...        ...
# 14930              0     1                      0         IT
# 14931              0     1                      0         IT
# 14932              0     1                      0         IT
# 14933              0     1                      0         IT
# 14938              0     1                      0         IT
#
#        satisfaction_level  last_evaluation  salary_num  department_num
# 61                   0.11             0.93           2               0
# 62                   0.10             0.95           2               0
# 63                   0.36             0.56           2               0
# 64                   0.11             0.94           2               0
# 65                   0.81             0.70           2               0
# ...                   ...              ...         ...             ...
# 14930                0.11             0.89           2               0
# 14931                0.87             0.88           2               0
# 14932                0.39             0.49           2               0
# 14933                0.10             0.94           2               0
# 14938                0.90             0.92           2               0
#
# [1227 rows x 11 columns]

# %%
main_df.drop(['department'],axis=1,inplace=True)

# %%
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years  satisfaction_level  \
# 0                  0     1                      0                0.38
# 1                  0     1                      0                0.80
# 2                  0     1                      0                0.11
# 3                  0     1                      0                0.72
# 4                  0     1                      0                0.37
# ...              ...   ...                    ...                 ...
# 14994              0     1                      0                0.40
# 14995              0     1                      0                0.37
# 14996              0     1                      0                0.37
# 14997              0     1                      0                0.11
# 14998              0     1                      0                0.37
#
#        last_evaluation  salary_num  department_num
# 0                 0.53           1               7
# 1                 0.86           2               7
# 2                 0.88           2               7
# 3                 0.87           1               7
# 4                 0.52           1               7
# ...                ...         ...             ...
# 14994             0.57           1               8
# 14995             0.48           1               8
# 14996             0.53           1               8
# 14997             0.96           1               8
# 14998             0.52           1               8
#
# [14999 rows x 10 columns]

# %%
X=main_df.drop(['left'],axis=1)

# %%
X
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  promotion_last_5years  satisfaction_level  \
# 0                  0                      0                0.38
# 1                  0                      0                0.80
# 2                  0                      0                0.11
# 3                  0                      0                0.72
# 4                  0                      0                0.37
# ...              ...                    ...                 ...
# 14994              0                      0                0.40
# 14995              0                      0                0.37
# 14996              0                      0                0.37
# 14997              0                      0                0.11
# 14998              0                      0                0.37
#
#        last_evaluation  salary_num  department_num
# 0                 0.53           1               7
# 1                 0.86           2               7
# 2                 0.88           2               7
# 3                 0.87           1               7
# 4                 0.52           1               7
# ...                ...         ...             ...
# 14994             0.57           1               8
# 14995             0.48           1               8
# 14996             0.53           1               8
# 14997             0.96           1               8
# 14998             0.52           1               8
#
# [14999 rows x 9 columns]

# %%
y=main_df['left']

# %%
y.size
# Out:
# 14999

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,)
# Out:
# C:\Users\thero\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
X_test
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 3958                3                   156                   3
# 13681               4                   208                   3
# 14738               7                   289                   4
# 2109                4                   201                   3
# 14144               5                   251                   4
# ...               ...                   ...                 ...
# 4239                4                   264                   3
# 5993                2                   284                   3
# 4708                3                   247                   3
# 13708               3                   183                   3
# 1841                5                   242                   5
#
#        Work_accident  promotion_last_5years  satisfaction_level  \
# 3958               0                      0                0.55
# 13681              0                      0                0.48
# 14738              0                      0                0.09
# 2109               1                      0                0.98
# 14144              0                      0                0.95
# ...              ...                    ...                 ...
# 4239               0                      0                0.98
# 5993               0                      0                0.42
# 4708               0                      0                0.81
# 13708              0                      0                0.54
# 1841               0                      0                0.84
#
#        last_evaluation  salary_num  department_num
# 3958              0.75           2               6
# 13681             0.90           1               7
# 14738             0.90           1               6
# 2109              0.92           1               8
# 14144             0.99           1               6
# ...                ...         ...             ...
# 4239              0.50           0               9
# 5993              0.37           0               9
# 4708              0.97           2               8
# 13708             0.76           1               7
# 1841              1.00           1               7
#
# [4500 rows x 9 columns]

# %%
y_test
# Out:
# 3958     0
# 13681    0
# 14738    1
# 2109     0
# 14144    0
#         ..
# 4239     0
# 5993     0
# 4708     0
# 13708    0
# 1841     1
# Name: left, Length: 4500, dtype: int64

# %%
# Standard Scaler

# %%
# Model Classification

# %%
# Decision Tree

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.tree import DecisionTreeClassifier

dt=DecisionTreeClassifier()

dt.fit(X_train,y_train)
# Out:
# C:\Users\thero\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
prediction_dt=dt.predict(X_test)

# %%
prediction_dt
# Out:
# array([0, 0, 1, ..., 0, 0, 1], dtype=int64)

# %%
y_test
# Out:
# 3958     0
# 13681    0
# 14738    1
# 2109     0
# 14144    0
#         ..
# 4239     0
# 5993     0
# 4708     0
# 13708    0
# 1841     1
# Name: left, Length: 4500, dtype: int64

# %%
accuracy_dt=accuracy_score(y_test,prediction_dt)*100

# %%
accuracy_dt
# Out:
# 97.91111111111111

# %%
X_test
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 3958                3                   156                   3
# 13681               4                   208                   3
# 14738               7                   289                   4
# 2109                4                   201                   3
# 14144               5                   251                   4
# ...               ...                   ...                 ...
# 4239                4                   264                   3
# 5993                2                   284                   3
# 4708                3                   247                   3
# 13708               3                   183                   3
# 1841                5                   242                   5
#
#        Work_accident  promotion_last_5years  satisfaction_level  \
# 3958               0                      0                0.55
# 13681              0                      0                0.48
# 14738              0                      0                0.09
# 2109               1                      0                0.98
# 14144              0                      0                0.95
# ...              ...                    ...                 ...
# 4239               0                      0                0.98
# 5993               0                      0                0.42
# 4708               0                      0                0.81
# 13708              0                      0                0.54
# 1841               0                      0                0.84
#
#        last_evaluation  salary_num  department_num
# 3958              0.75           2               6
# 13681             0.90           1               7
# 14738             0.90           1               6
# 2109              0.92           1               8
# 14144             0.99           1               6
# ...                ...         ...             ...
# 4239              0.50           0               9
# 5993              0.37           0               9
# 4708              0.97           2               8
# 13708             0.76           1               7
# 1841              1.00           1               7
#
# [4500 rows x 9 columns]

# %%
Catagory=['Employee will stay','Employee will Leave']

# %%
custom_dt=[[1,500,3,6,0,0.90,0.89,1,8]]

# %%
print(int(dt.predict(custom_dt)))
# Out:
# 1

# %%
Catagory[int(dt.predict(custom_dt))]
# Out:
# 'Employee will Leave'

# %%
dt.feature_importances_
# Out:
# array([1.09182874e-01, 8.18645157e-02, 1.43886351e-01, 2.03478746e-03,
#        9.51468380e-06, 4.87410565e-01, 1.54187992e-01, 8.07303288e-03,
#        1.33503669e-02])

# %%
feature_importance=pd.DataFrame(dt.feature_importances_,index=X_train.columns,columns=['Importance']).sort_values('Importance',ascending=False)

# %%
feature_importance
# Out:
#                        Importance
# satisfaction_level       0.487411
# last_evaluation          0.154188
# time_spend_company       0.143886
# number_project           0.109183
# average_montly_hours     0.081865
# department_num           0.013350
# salary_num               0.008073
# Work_accident            0.002035
# promotion_last_5years    0.000010

# %%
X_train
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 7076                3                   210                   2
# 8346                3                   221                   3
# 12448               2                   159                   3
# 13959               4                   209                   8
# 9313                4                   155                   3
# ...               ...                   ...                 ...
# 61                  7                   308                   4
# 10817               2                   103                   3
# 1967                2                   143                   3
# 12507               2                   158                   3
# 8088                4                   171                   4
#
#        Work_accident  promotion_last_5years  satisfaction_level  \
# 7076               0                      0                0.57
# 8346               0                      0                0.28
# 12448              0                      0                0.36
# 13959              1                      0                0.99
# 9313               0                      0                1.00
# ...              ...                    ...                 ...
# 61                 0                      0                0.11
# 10817              0                      0                0.52
# 1967               1                      0                0.41
# 12507              0                      0                0.39
# 8088               0                      0                0.63
#
#        last_evaluation  salary_num  department_num
# 7076              0.70           2               8
# 8346              0.77           0               7
# 12448             0.48           1               6
# 13959             0.60           2               0
# 9313              0.96           2               8
# ...                ...         ...             ...
# 61                0.93           2               0
# 10817             0.38           2               8
# 1967              0.47           1               9
# 12507             0.54           1               8
# 8088              0.59           1               1
#
# [10499 rows x 9 columns]

# %%
#KNN

# %%
# Data Processing of KNN

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler().fit(X_train)
X_train_std=sc.transform(X_train)
X_test_std=sc.transform(X_test)

# %%
X_train_std
# Out:
# array([[-0.64685986,  0.18385385, -1.03240944, ..., -0.0830803 ,
#          1.04370852,  0.73930469],
#        [-0.64685986,  0.40422391, -0.34428941, ...,  0.32329035,
#         -2.16504572,  0.38908315],
#        [-1.45680401, -0.83786192, -0.34428941, ..., -1.36024521,
#         -0.5606686 ,  0.03886161],
#        ...,
#        [-1.45680401, -1.1584002 , -0.34428941, ..., -1.41829816,
#         -0.5606686 ,  1.08952622],
#        [-1.45680401, -0.85789557, -0.34428941, ..., -1.01192751,
#         -0.5606686 ,  0.73930469],
#        [ 0.16308429, -0.59745821,  0.34383062, ..., -0.72166275,
#         -0.5606686 , -1.71224607]])

# %%
X_test_std
# Out:
# array([[-0.64685986, -0.89796285, -0.34428941, ...,  0.20718445,
#          1.04370852,  0.03886161],
#        [ 0.16308429,  0.14378656, -0.34428941, ...,  1.07797871,
#         -0.5606686 ,  0.38908315],
#        [ 2.59291673,  1.7665116 ,  0.34383062, ...,  1.07797871,
#         -0.5606686 ,  0.03886161],
#        ...,
#        [-0.64685986,  0.92509862, -0.34428941, ...,  1.48434936,
#          1.04370852,  0.73930469],
#        [-0.64685986, -0.3570545 , -0.34428941, ...,  0.2652374 ,
#         -0.5606686 ,  0.38908315],
#        [ 0.97302844,  0.82493041,  1.03195065, ...,  1.65850821,
#         -0.5606686 ,  0.38908315]])

# %%
from sklearn.neighbors import KNeighborsClassifier

knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_std,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
prediction_knn=knn.predict(X_test_std)

# %%
accuracy_knn=accuracy_score(y_test,prediction_knn)*100

# %%
accuracy_knn
# Out:
# 95.75555555555556

# %%
prediction_knn
# Out:
# array([0, 0, 1, ..., 0, 0, 1], dtype=int64)

# %%
y_test
# Out:
# 3958     0
# 13681    0
# 14738    1
# 2109     0
# 14144    0
#         ..
# 4239     0
# 5993     0
# 4708     0
# 13708    0
# 1841     1
# Name: left, Length: 4500, dtype: int64

# %%
k_range=range(1,26)
scores={}
scores_list=[]


for k in k_range:
    knn=KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_std,y_train)
    prediction_knn=knn.predict(X_test_std)
    scores[k]=accuracy_score(y_test,prediction_knn)*100
    scores_list.append(accuracy_score(y_test,prediction_knn))

# %%
scores
# Out:
# {1: 96.73333333333333,
#  2: 96.4888888888889,
#  3: 95.75555555555556,
#  4: 95.71111111111111,
#  5: 95.17777777777778,
#  6: 95.73333333333333,
#  7: 95.51111111111112,
#  8: 95.66666666666667,
#  9: 95.28888888888889,
#  10: 95.33333333333334,
#  11: 94.95555555555556,
#  12: 95.13333333333334,
#  13: 94.77777777777779,
#  14: 95.0,
#  15: 94.77777777777779,
#  16: 94.86666666666666,
#  17: 94.53333333333333,
#  18: 94.68888888888888,
#  19: 94.53333333333333,
#  20: 94.62222222222222,
#  21: 94.35555555555555,
#  22: 94.39999999999999,
#  23: 94.22222222222221,
#  24: 94.35555555555555,
#  25: 94.22222222222221}

# %%
scores_list
# Out:
# [0.9673333333333334,
#  0.9648888888888889,
#  0.9575555555555556,
#  0.9571111111111111,
#  0.9517777777777777,
#  0.9573333333333334,
#  0.9551111111111111,
#  0.9566666666666667,
#  0.9528888888888889,
#  0.9533333333333334,
#  0.9495555555555556,
#  0.9513333333333334,
#  0.9477777777777778,
#  0.95,
#  0.9477777777777778,
#  0.9486666666666667,
#  0.9453333333333334,
#  0.9468888888888889,
#  0.9453333333333334,
#  0.9462222222222222,
#  0.9435555555555556,
#  0.944,
#  0.9422222222222222,
#  0.9435555555555556,
#  0.9422222222222222]

# %%
plt.plot(k_range,scores_list)

# %%
X_test.head(1)
# Out:
#       number_project  average_montly_hours  time_spend_company  Work_accident  \
# 3958               3                   156                   3              0
#
#       promotion_last_5years  satisfaction_level  last_evaluation  salary_num  \
# 3958                      0                0.55             0.75           2
#
#       department_num
# 3958               6

# %%
X_knn=np.array([[20,500,10,6,0,0.10,0.30,1,8]])
X_knn_std=sc.transform(X_knn)

# %%
X_knn_std
# Out:
# array([[13.12219067,  5.99361017,  4.47255079, 16.59216633, -0.14697495,
#         -2.07107398, -2.40519832, -0.5606686 ,  0.73930469]])

# %%
X_knn_prediction=knn.predict(X_knn_std)

# %%
X_knn_prediction
# Out:
# array([1], dtype=int64)

# %%
Catagory[int(dt.predict(custom_dt))]
# Out:
# 'Employee will Leave'

# %%
algorithms=['Decision Tree','KNN']
scores=[accuracy_dt,accuracy_knn]
plt.xlabel("Algorithms")
plt.ylabel("Accuracy Score")
sns.barplot(algorithms,scores)
plt.show()
